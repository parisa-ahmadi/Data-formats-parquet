# %%
pip install fastparquet
# Out:
# ...
#
# ...
#                                               0.0/668.7 kB ? eta -:--:--
#                                               0.0/668.7 kB ? eta -:--:--
#                                               0.0/668.7 kB ? eta -:--:--
#                                               0.0/668.7 kB ? eta -:--:--
#                                               0.0/668.7 kB ? eta -:--:--
#                                               0.0/668.7 kB ? eta -:--:--
#                                               0.0/668.7 kB ? eta -:--:--
#                                               0.0/668.7 kB ? eta -:--:--
#                                               10.2/668.7 kB ? eta -:--:--
#                                               10.2/668.7 kB ? eta -:--:--
#                                               10.2/668.7 kB ? eta -:--:--
#                                               10.2/668.7 kB ? eta -:--:--
#                                               10.2/668.7 kB ? eta -:--:--
# ...

# %%
pip install pyarrow
# Out:
# ...
#                                               0.0/24.6 MB ? eta -:--:--
#                                               0.0/24.6 MB ? eta -:--:--
#                                               0.0/24.6 MB ? eta -:--:--
#                                               0.0/24.6 MB ? eta -:--:--
#                                               0.0/24.6 MB ? eta -:--:--
#                                               0.0/24.6 MB ? eta -:--:--
#                                               0.0/24.6 MB ? eta -:--:--
#                                               0.0/24.6 MB ? eta -:--:--
#                                               0.0/24.6 MB ? eta -:--:--
#                                               0.0/24.6 MB ? eta -:--:--
#                                               0.0/24.6 MB ? eta -:--:--
#                                               0.0/24.6 MB ? eta -:--:--
#                                               0.0/24.6 MB ? eta -:--:--
# ...

# %%
import pandas as pd

# %%
file = r"G:\tajvar\Real Projects\Magic AI\data\train-00035-of-05534-4af1fa8b5ec251d2.parquet"

# %%
df = pd.read_parquet(file, engine = "auto" )
df
# Out:
#                                                   content  \
# 0       Councils ‘still waiting’ on fire safety fundin...
# 1       Established in 1933, Ein Harod Apiary has won ...
# 2       Intelligent lyrics and well-thought-out music ...
# 3       10 May 2016, full story here\nBy Jean Kennedy ...
# 4       The. The term “Blue Whale” comes from the phen...
# ...                                                   ...
# 174914  - Billion Dollar Agent,\n- Over 7,500 homes so...
# 174915  Butler Stevens Sturtevant (1 September 1899 – ...
# 174916  Shareholders of large and small companies have...
# 174917  0 items, $0.00\nHome » Shop by Product » Dolls...
# 174918  Nathan Bedford Forrest\nNathan Bedford Forrest...
#
#                                                       url           timestamp  \
# 0       http://www.frmjournal.com/news/news_detail.cou... 2018-03-17 16:09:16
# 1       http://www.fruitoftheland.com/index.php?route=... 2018-03-17 16:07:37
# ...
